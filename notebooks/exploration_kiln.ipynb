# %% [markdown]
# # Kiln Exploration
#
# Exploratory data analysis for the **cement kiln** (pyroprocessing) subsystem.
#
# Goals:
# - Understand sensor distributions and missingness
# - Relate burning-zone temperature / fuel / feed to clinker free lime
# - Identify candidate features for the kiln quality model
#
# > TODO: extend with correlation analysis, lag studies, and upset detection.

# %%
import pandas as pd

from src.data_ingest import clean_timeseries, load_timeseries

df = clean_timeseries(load_timeseries('data/sample_timeseries.csv'))
df.head()

# %%
# Basic summary statistics
df.describe()

# %%
# TODO: plot burning_zone_temp_c vs fuel_rate_tph and inspect dynamics
df.plot(x='timestamp', y='burning_zone_temp_c')
