# %% [markdown]
# # Mill Exploration
#
# Exploratory data analysis for the **cement mill** (grinding) subsystem.
#
# Goals:
# - Understand the relationship between operating conditions and Blaine fineness
# - Explore specific power consumption (kWh/t) drivers
# - Identify candidate features for the mill quality/efficiency model
#
# > TODO: join lab Blaine measurements to operating data via merge_asof.

# %%
import pandas as pd

from src.data_ingest import clean_lab, load_lab

lab = clean_lab(load_lab('data/sample_lab.csv'))
lab.head()

# %%
# Distribution of Blaine fineness
lab['blaine_fineness_cm2g'].describe()

# %%
# TODO: relate Blaine fineness to free lime / SO3 and grinding conditions
lab.plot(x='timestamp', y='blaine_fineness_cm2g')
